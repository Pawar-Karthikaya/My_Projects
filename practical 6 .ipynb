# %%
import pandas as pd
df=pd.read_csv("salaries.csv")
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
inputs=df.drop("salary",axis='columns')
targat=df['salary']

# %%
from sklearn.preprocessing import LabelEncoder
rank=LabelEncoder()
discipline=LabelEncoder()
sex=LabelEncoder()

# %%
inputs['rank_n']=rank.fit_transform(inputs['rank'])
inputs['discipline_n']=rank.fit_transform(inputs['rank'])
inputs['phd_n']=rank.fit_transform(inputs['rank'])
inputs['service_n']=rank.fit_transform(inputs['rank'])
inputs['sex_n']=rank.fit_transform(inputs['rank'])
inputs
# Out:
#          rank discipline  phd  service     sex  rank_n  discipline_n  phd_n  \
# 0        Prof          B   56       49    Male       2             2      2
# 1        Prof          A   12        6    Male       2             2      2
# 2        Prof          A   23       20    Male       2             2      2
# 3        Prof          A   40       31    Male       2             2      2
# 4        Prof          B   20       18    Male       2             2      2
# ..        ...        ...  ...      ...     ...     ...           ...    ...
# 73       Prof          B   18       10  Female       2             2      2
# 74  AssocProf          B   19        6  Female       0             0      0
# 75       Prof          B   17       17  Female       2             2      2
# 76       Prof          A   28       14  Female       2             2      2
# 77       Prof          A   23       15  Female       2             2      2
#
#     service_n  sex_n
# 0           2      2
# ...

# %%
# Import the necessary libraries
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from graphviz import Source

# Load the dataset
iris = load_iris()
X = iris.data[:, 2:] # petal length and width
y = iris.target

# DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(criterion='entropy',
								max_depth=2)
tree_clf.fit(X, y)

# Plot the decision tree graph
export_graphviz(
	tree_clf,
	out_file="iris_tree.dot",
	feature_names=iris.feature_names[2:],
	class_names=iris.target_names,
	rounded=True,
	filled=True
)

with open("iris_tree.dot") as f:
	dot_graph = f.read()
	
Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78                 kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79             proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80         else:
#
# ~\anaconda3\lib\site-packages\graphviz\backend\execute.py in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     100
#
# ...

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
